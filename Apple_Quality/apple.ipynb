# %%
import pandas as pd 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
class help:
    def __init__(self):
        self.c="NULL"
    def reads(self,k):
        self.c = pd.read_csv(k)
        return self.c
if __name__=='__main__':
    h=help()
    df=h.reads(r"C:\Users\prane\Downloads\archive (12)\apple_quality.csv")

# %%
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4001 entries, 0 to 4000
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A_id         4000 non-null   float64
#  1   Size         4000 non-null   float64
#  2   Weight       4000 non-null   float64
#  3   Sweetness    4000 non-null   float64
#  4   Crunchiness  4000 non-null   float64
#  5   Juiciness    4000 non-null   float64
#  6   Ripeness     4000 non-null   float64
#  7   Acidity      4001 non-null   object
#  8   Quality      4000 non-null   object
# dtypes: float64(7), object(2)
# memory usage: 281.4+ KB

# %%
df.describe()
# Out:
#               A_id         Size       Weight    Sweetness  Crunchiness  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean   1999.500000    -0.503015    -0.989547    -0.470479     0.985478
# std    1154.844867     1.928059     1.602507     1.943441     1.402757
# min       0.000000    -7.151703    -7.149848    -6.894485    -6.055058
# 25%     999.750000    -1.816765    -2.011770    -1.738425     0.062764
# 50%    1999.500000    -0.513703    -0.984736    -0.504758     0.998249
# 75%    2999.250000     0.805526     0.030976     0.801922     1.894234
# max    3999.000000     6.406367     5.790714     6.374916     7.619852
#
#          Juiciness     Ripeness
# count  4000.000000  4000.000000
# mean      0.512118     0.498277
# std       1.930286     1.874427
# min      -5.961897    -5.864599
# 25%      -0.801286    -0.771677
# 50%       0.534219     0.503445
# 75%       1.835976     1.766212
# max       7.364403     7.237837

# %%
df.isna().value_counts()
# Out:
# A_id   Size   Weight  Sweetness  Crunchiness  Juiciness  Ripeness  Acidity  Quality
# False  False  False   False      False        False      False     False    False      4000
# True   True   True    True       True         True       True      False    True          1
# Name: count, dtype: int64

# %%
df.drop(index=df.tail(1).index,inplace=True)

# %%
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity Quality
# ...

# %%
df['A_id']=df['A_id'].astype(int)

# %%
df
# Out:
#       A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...    ...       ...       ...        ...          ...        ...       ...
# 3995  3995  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity Quality
# 0     -0.491590483    good
# ...

# %%
df['Acidity']=df['Acidity'].astype(float)

# %%
df['Acidity']=df['Acidity'].apply(lambda x:format(x,'.2f'))

# %%
df
# Out:
#       A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...    ...       ...       ...        ...          ...        ...       ...
# 3995  3995  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#      Acidity Quality
# 0      -0.49    good
# ...

# %%
df['Ripeness']=df['Ripeness'].apply(lambda x:format(x,'.2f'))

# %%
df[["Size","Weight","Sweetness","Crunchiness","Juiciness"]]=df[["Size","Weight","Sweetness","Crunchiness","Juiciness"]].applymap(lambda x:format(x,'.3f'))
# Out:
# C:\Users\prane\AppData\Local\Temp\ipykernel_17448\1965303287.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[["Size","Weight","Sweetness","Crunchiness","Juiciness"]]=df[["Size","Weight","Sweetness","Crunchiness","Juiciness"]].applymap(lambda x:format(x,'.3f'))

# %%
df
# Out:
#       A_id    Size  Weight Sweetness Crunchiness Juiciness Ripeness Acidity  \
# 0        0  -3.970  -2.512     5.346      -1.012     1.845     0.33   -0.49
# 1        1  -1.195  -2.839     3.664       1.588     0.853     0.87   -0.72
# 2        2  -0.292  -1.351    -1.738      -0.343     2.839    -0.04    2.62
# 3        3  -0.657  -2.272     1.325      -0.098     3.638    -3.41    0.79
# 4        4   1.364  -1.297    -0.385      -0.553     3.031    -1.30    0.50
# ...    ...     ...     ...       ...         ...       ...      ...     ...
# 3995  3995   0.059  -1.067    -3.715       0.473     1.698     2.24    0.14
# 3996  3996  -0.293   1.949    -0.204      -0.640     0.025    -1.09    1.85
# 3997  3997  -2.635  -2.138    -2.440       0.657     2.200     4.76   -1.33
# 3998  3998  -4.008  -1.779     2.366      -0.200     2.161     0.21   -2.23
# 3999  3999   0.279  -1.716     0.121      -1.154     1.267    -0.78    1.60
#
#      Quality
# 0       good
# 1       good
# ...

# %%
y=df['Sweetness'].sample(20)
x=df['Quality'].sample(20)
plt.bar(x,y)
# Out:
# <BarContainer object of 20 artists>

# %%
plt.scatter(x=y,y=df['Ripeness'].sample(20))

# %%
plt.hist(df['Acidity'].sample(50),bins=12)
plt.grid(True,which='both',linestyle='-')
plt.legend()
# Out:
# C:\Users\prane\AppData\Local\Temp\ipykernel_17448\1359826468.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df['Size'] = pd.to_numeric(df['Size'])
Q1 = df['Size'].quantile(0.25)
Q3 = df['Size'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Define the bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
k=(df['Size']<lower_bound)|(df['Size']>upper_bound)
df=df[~k]

# %%
df
# Out:
#       A_id   Size  Weight Sweetness Crunchiness Juiciness Ripeness Acidity  \
# 0        0 -3.970  -2.512     5.346      -1.012     1.845     0.33   -0.49
# 1        1 -1.195  -2.839     3.664       1.588     0.853     0.87   -0.72
# 2        2 -0.292  -1.351    -1.738      -0.343     2.839    -0.04    2.62
# 3        3 -0.657  -2.272     1.325      -0.098     3.638    -3.41    0.79
# 4        4  1.364  -1.297    -0.385      -0.553     3.031    -1.30    0.50
# ...    ...    ...     ...       ...         ...       ...      ...     ...
# 3995  3995  0.059  -1.067    -3.715       0.473     1.698     2.24    0.14
# 3996  3996 -0.293   1.949    -0.204      -0.640     0.025    -1.09    1.85
# 3997  3997 -2.635  -2.138    -2.440       0.657     2.200     4.76   -1.33
# 3998  3998 -4.008  -1.779     2.366      -0.200     2.161     0.21   -2.23
# 3999  3999  0.279  -1.716     0.121      -1.154     1.267    -0.78    1.60
#
#      Quality
# 0       good
# 1       good
# 2        bad
# ...

# %%
df['Weight'] = pd.to_numeric(df['Size'])
Q1 = df['Weight'].quantile(0.25)
Q3 = df['Weight'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Define the bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
t=(df['Weight']<lower_bound)|(df['Weight']>upper_bound)
df[t].sort_values(by=['Weight'],ascending=True)
df=df[~t]
# Out:
# C:\Users\prane\AppData\Local\Temp\ipykernel_17448\1549733362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Weight'] = pd.to_numeric(df['Size'])

# %%
df
# Out:
#       A_id   Size  Weight Sweetness Crunchiness Juiciness Ripeness Acidity  \
# 0        0 -3.970  -3.970     5.346      -1.012     1.845     0.33   -0.49
# 1        1 -1.195  -1.195     3.664       1.588     0.853     0.87   -0.72
# 2        2 -0.292  -0.292    -1.738      -0.343     2.839    -0.04    2.62
# 3        3 -0.657  -0.657     1.325      -0.098     3.638    -3.41    0.79
# 4        4  1.364   1.364    -0.385      -0.553     3.031    -1.30    0.50
# ...    ...    ...     ...       ...         ...       ...      ...     ...
# 3995  3995  0.059   0.059    -3.715       0.473     1.698     2.24    0.14
# 3996  3996 -0.293  -0.293    -0.204      -0.640     0.025    -1.09    1.85
# 3997  3997 -2.635  -2.635    -2.440       0.657     2.200     4.76   -1.33
# 3998  3998 -4.008  -4.008     2.366      -0.200     2.161     0.21   -2.23
# 3999  3999  0.279   0.279     0.121      -1.154     1.267    -0.78    1.60
#
#      Quality
# 0       good
# 1       good
# 2        bad
# ...

# %%
df['Crunchiness'] = pd.to_numeric(df['Crunchiness'])
Q1 = df['Crunchiness'].quantile(0.25)
Q3 = df['Crunchiness'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Define the bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
t=(df['Crunchiness']<lower_bound)|(df['Crunchiness']>upper_bound)
df[t].sort_values(by=['Crunchiness'],ascending=True)
df=df[~t]

# %%
df['Juiciness'] = pd.to_numeric(df['Juiciness'])
Q1 = df['Juiciness'].quantile(0.25)
Q3 = df['Juiciness'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Define the bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
p=(df['Juiciness']<lower_bound)|(df['Juiciness']>upper_bound)
df[p].sort_values(by=['Juiciness'],ascending=True)
df=df[~p]
# Out:
# C:\Users\prane\AppData\Local\Temp\ipykernel_17448\3120860638.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Juiciness'] = pd.to_numeric(df['Juiciness'])

# %%
df
# Out:
#       A_id   Size  Weight Sweetness  Crunchiness  Juiciness Ripeness Acidity  \
# 0        0 -3.970  -3.970     5.346       -1.012      1.845     0.33   -0.49
# 1        1 -1.195  -1.195     3.664        1.588      0.853     0.87   -0.72
# 2        2 -0.292  -0.292    -1.738       -0.343      2.839    -0.04    2.62
# 3        3 -0.657  -0.657     1.325       -0.098      3.638    -3.41    0.79
# 4        4  1.364   1.364    -0.385       -0.553      3.031    -1.30    0.50
# ...    ...    ...     ...       ...          ...        ...      ...     ...
# 3995  3995  0.059   0.059    -3.715        0.473      1.698     2.24    0.14
# 3996  3996 -0.293  -0.293    -0.204       -0.640      0.025    -1.09    1.85
# 3997  3997 -2.635  -2.635    -2.440        0.657      2.200     4.76   -1.33
# 3998  3998 -4.008  -4.008     2.366       -0.200      2.161     0.21   -2.23
# 3999  3999  0.279   0.279     0.121       -1.154      1.267    -0.78    1.60
#
#      Quality
# 0       good
# 1       good
# ...

# %%
df['Ripeness'] = pd.to_numeric(df['Ripeness'])
Q1 = df['Ripeness'].quantile(0.25)
Q3 = df['Ripeness'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Define the bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
p=(df['Ripeness']<lower_bound)|(df['Ripeness']>upper_bound)
df[p].sort_values(by=['Ripeness'],ascending=True)
df=df[~p]

# %%
df['Acidity'] = pd.to_numeric(df['Acidity'])
Q1 = df['Acidity'].quantile(0.25)
Q3 = df['Acidity'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Define the bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
p=(df['Acidity']<lower_bound)|(df['Acidity']>upper_bound)
df[p].sort_values(by=['Acidity'],ascending=True)
df=df[~p]
# Out:
# C:\Users\prane\AppData\Local\Temp\ipykernel_17448\838071713.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Acidity'] = pd.to_numeric(df['Acidity'])

# %%
g=sns.PairGrid(df)
g.map(sns.regplot)

# %%
k=df.select_dtypes(include='number').columns #new technique for select

# %%
for i in range(0,len(k)):
    sns.displot(df[k[i]],kind='kde')

# %%
df['Size'].skew()
# Out:
# np.float64(-0.0022204866225096344)

# %%
# Sample 20 rows from the 'Size' and 'Acidity' columns
sample_data = df[['Size', 'Acidity']].sample(20)

# Create the violin plot
sns.violinplot(y='Size', x='Acidity', data=sample_data)
# Out:
# <Axes: xlabel='Acidity', ylabel='Size'>

# %%
from sklearn.preprocessing import normalize

# %%
df.columns
# Out:
# Index(['A_id', 'Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness',
#        'Ripeness', 'Acidity', 'Quality'],
#       dtype='object')

# %%
mn = df[['Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness', 'Ripeness', 'Acidity']].values.tolist()

# %%
k=normalize(mn)

# %%
df
# Out:
#       A_id   Size  Weight Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0 -3.970  -3.970     5.346       -1.012      1.845      0.33
# 1        1 -1.195  -1.195     3.664        1.588      0.853      0.87
# 2        2 -0.292  -0.292    -1.738       -0.343      2.839     -0.04
# 3        3 -0.657  -0.657     1.325       -0.098      3.638     -3.41
# 4        4  1.364   1.364    -0.385       -0.553      3.031     -1.30
# ...    ...    ...     ...       ...          ...        ...       ...
# 3995  3995  0.059   0.059    -3.715        0.473      1.698      2.24
# 3996  3996 -0.293  -0.293    -0.204       -0.640      0.025     -1.09
# 3997  3997 -2.635  -2.635    -2.440        0.657      2.200      4.76
# 3998  3998 -4.008  -4.008     2.366       -0.200      2.161      0.21
# 3999  3999  0.279   0.279     0.121       -1.154      1.267     -0.78
#
#       Acidity Quality
# 0       -0.49    good
# 1       -0.72    good
# 2        2.62     bad
# 3        0.79    good
# ...

# %%
from sklearn.preprocessing import OneHotEncoder,MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
x=df[['Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness', 'Ripeness', 'Acidity']]
y=df['Quality']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', MinMaxScaler(), ['Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness', 'Ripeness', 'Acidity']),  # Apply MinMaxScaler to numerical features  # Apply OneHotEncoder to categorical features (if any)
    ],
)

# %%
model = Pipeline([
    ("pre", preprocessor),
    ("log", LogisticRegression(penalty='l2',class_weight='balanced'))  
])

# %%
model.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(transformers=[('num', MinMaxScaler(),
#                                                   ['Size', 'Weight',
#                                                    'Sweetness', 'Crunchiness',
#                                                    'Juiciness', 'Ripeness',
#                                                    'Acidity'])])),
#                 ('log', LogisticRegression(class_weight='balanced'))])

# %%
pre=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
accuracy_score(y_test,pre)
# Out:
# 0.7322121604139715

# %%
ma=confusion_matrix(y_test,pre)

# %%
sns.heatmap(ma)
# Out:
# <Axes: >

# %%
ma
# Out:
# array([[276, 101],
#        [106, 290]])
